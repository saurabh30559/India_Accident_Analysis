# %%
import pandas as pd
import numpy as np

# %%
Data=pd.read_csv("D:/stat-road-ac-2013-2016 Sql.csv")

# %%
Data
# Out:
#    SI. No.                 States/UTs  \
# 0        1             Andhra Pradesh
# 1        2          Arunachal Pradesh
# 2        3                      Assam
# 3        4                      Bihar
# 4        5               Chhattisgarh
# 5        6                        Goa
# 6        7                    Gujarat
# 7        8                    Haryana
# 8        9           Himachal Pradesh
# 9       10            Jammu & Kashmir
# 10      11                  Jharkhand
# 11      12                  Karnataka
# 12      13                     Kerala
# 13      14             Madhya Pradesh
# 14      15                Maharashtra
# 15      16                    Manipur
# 16      17                  Meghalaya
# 17      18                    Mizoram
# 18      19                   Nagaland
# 19      20                     Odisha
# 20      21                     Punjab
# 21      22                  Rajasthan
# 22      23                     Sikkim
# ...

# %%
Data['Avreage of Total No of Accidents Per lakh Population - 2013/14/15/16']= Data['Avreage of Total No of Accidents Per lakh Population - 2013/14/15/16'].fillna(Data['Avreage of Total No of Accidents Per lakh Population - 2013/14/15/16'].mean())

# %%
Data.isnull().sum()
# Out:
# SI. No.                                                                                     0
# States/UTs                                                                                  0
# State/UT-Wise Total Number of Road Accidents during - 2013                                  1
# State/UT-Wise Total Number of Road Accidents during - 2014                                  0
# State/UT-Wise Total Number of Road Accidents during - 2015                                  0
# State/UT-Wise Total Number of Road Accidents during - 2016                                  0
# Share of States/UTs in Total Number of Road Accidents - 2013                                0
# Share of States/UTs in Total Number of Road Accidents - 2014                                0
# Share of States/UTs in Total Number of Road Accidents - 2015                                0
# Share of States/UTs in Total Number of Road Accidents - 2016                                0
# ...

# %%
Data.isnull().sum()
# Out:
# SI. No.                                                                                     0
# States/UTs                                                                                  0
# State/UT-Wise Total Number of Road Accidents during - 2013                                  1
# State/UT-Wise Total Number of Road Accidents during - 2014                                  0
# State/UT-Wise Total Number of Road Accidents during - 2015                                  0
# State/UT-Wise Total Number of Road Accidents during - 2016                                  0
# Share of States/UTs in Total Number of Road Accidents - 2013                                0
# Share of States/UTs in Total Number of Road Accidents - 2014                                0
# Share of States/UTs in Total Number of Road Accidents - 2015                                0
# Share of States/UTs in Total Number of Road Accidents - 2016                                0
# ...

# %%
Data.head()
# Out:
#   SI. No.         States/UTs  \
# 0       1     Andhra Pradesh
# 1       2  Arunachal Pradesh
# 2       3              Assam
# 3       4              Bihar
# 4       5       Chhattisgarh
#
#    State/UT-Wise Total Number of Road Accidents during - 2013  \
# 0                                            43482.0
# 1                                              308.0
# 2                                             7211.0
# 3                                            10200.0
# 4                                            13657.0
#
#    State/UT-Wise Total Number of Road Accidents during - 2014  \
# 0                                              24440
# 1                                                205
# 2                                               7144
# 3                                               9556
# 4                                              13821
#
#    State/UT-Wise Total Number of Road Accidents during - 2015  \
# ...

# %%
Data['Avreage of Total No of Accidents Per lakh Population - 2013/14/15/16'].value_counts().nlargest(5)
# Out:
# 48.5    2
# 24.1    2
# 33.4    1
# 34.5    1
# 99.5    1
# Name: Avreage of Total No of Accidents Per lakh Population - 2013/14/15/16, dtype: int64

# %%
Data = Data.sort_values(by=["Avreage of Total No of Accidents Per lakh Population - 2013/14/15/16"], ascending=False)

# %%
Data.head()
# Out:
#    SI. No.                 States/UTs  \
# 5        6                        Goa
# 12      13                     Kerala
# 23      24                 Tamil Nadu
# 35      36                 Puducherry
# 11      12                  Karnataka
# 13      14             Madhya Pradesh
# 4        5               Chhattisgarh
# 9       10            Jammu & Kashmir
# 14      15                Maharashtra
# 8        9           Himachal Pradesh
# 29      30  Andaman & Nicobar Islands
# 24      25                  Telangana
# 7        8                    Haryana
# 36   Total                      Total
# 33      34                      Delhi
# 6        7                    Gujarat
# 22      23                     Sikkim
# 0        1             Andhra Pradesh
# 21      22                  Rajasthan
# 15      16                    Manipur
# 30      31                 Chandigarh
# 19      20                     Odisha
# 20      21                     Punjab
# ...

# %%
Star_Road=Data[["SI. No.","States/UTs","State/UT-Wise Total Number of Road Accidents during - 2013/14/15/16","Average Total No of Road Accidents per 10,000 Vehicles - 2013/14/15","Avreage of Total No of Accidents Per lakh Population - 2013/14/15/16"]]

# %%
Total_NO_Of_Accident_StateWise=Star_Road.sort_values(by=["State/UT-Wise Total Number of Road Accidents during - 2013/14/15/16"],ascending=False)

# %%
Total_NO_Of_Accident_StateWise
# Out:
#    SI. No.                 States/UTs  \
# 36   Total                      Total
# 23      24                 Tamil Nadu
# 14      15                Maharashtra
# 13      14             Madhya Pradesh
# 11      12                  Karnataka
# 12      13                     Kerala
# 27      28              Uttar Pradesh
# 0        1             Andhra Pradesh
# 21      22                  Rajasthan
# 6        7                    Gujarat
# 24      25                  Telangana
# 4        5               Chhattisgarh
# 28      29                West Bengal
# 7        8                    Haryana
# 19      20                     Odisha
# 3        4                      Bihar
# 33      34                      Delhi
# 2        3                      Assam
# 20      21                     Punjab
# 9       10            Jammu & Kashmir
# 10      11                  Jharkhand
# 5        6                        Goa
# 8        9           Himachal Pradesh
# ...

# %%
Total_NO_Of_Accident_StateWise.tail()#Nagaland has the lowest Accident count in the whole country
# Out:
#    SI. No.            States/UTs  \
# 18      19              Nagaland
# 17      18               Mizoram
# 31      32  Dadra & Nagar Haveli
# 32      33           Daman & Diu
# 34      35           Lakshadweep
#
#     State/UT-Wise Total Number of Road Accidents during - 2013/14/15/16  \
# 18                                                505
# 17                                                399
# 31                                                317
# 32                                                239
# 34                                                  6
#
#     Average Total No of Road Accidents per 10,000 Vehicles - 2013/14/15  \
# 18                                                4.5
# 17                                                7.9
# 31                                                8.1
# 32                                                5.8
# 34                                                1.3
#
# ...

# %%
Total_NO_Of_Accident_StateWise.head()
# Tamil Nadu has the highest Accidents in the country 
#Maharashtra is the second topper in this list.
# Out:
#    SI. No.      States/UTs  \
# 36   Total           Total
# 23      24      Tamil Nadu
# 14      15     Maharashtra
# 13      14  Madhya Pradesh
# 11      12       Karnataka
#
#     State/UT-Wise Total Number of Road Accidents during - 2013/14/15/16  \
# 36                                            1957951
# 23                                             273978
# 14                                             228329
# 13                                             214201
# 11                                             176147
#
#     Average Total No of Road Accidents per 10,000 Vehicles - 2013/14/15  \
# 36                                               25.4
# 23                                               32.4
# 14                                               26.9
# 13                                               54.5
# 11                                               33.0
#
#     Avreage of Total No of Accidents Per lakh Population - 2013/14/15/16
# ...

# %%
Star_Road
# Out:
#    SI. No.                 States/UTs  \
# 5        6                        Goa
# 12      13                     Kerala
# 23      24                 Tamil Nadu
# 35      36                 Puducherry
# 11      12                  Karnataka
# 13      14             Madhya Pradesh
# 4        5               Chhattisgarh
# 9       10            Jammu & Kashmir
# 14      15                Maharashtra
# 8        9           Himachal Pradesh
# 29      30  Andaman & Nicobar Islands
# 24      25                  Telangana
# 7        8                    Haryana
# 36   Total                      Total
# 33      34                      Delhi
# 6        7                    Gujarat
# 22      23                     Sikkim
# 0        1             Andhra Pradesh
# 21      22                  Rajasthan
# 15      16                    Manipur
# 30      31                 Chandigarh
# 19      20                     Odisha
# 20      21                     Punjab
# ...

# %%
datatoexcel= pd.ExcelWriter('C:/Users/saurabh lembhe/Desktop/Star_Road_Analysis1.xlsx')
Star_Road.to_excel(datatoexcel)
datatoexcel.save()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16072\3575339112.py in <module>
# ----> 1 datatoexcel= pd.ExcelWriter('C:/Users/saurabh lembhe/Desktop/Star_Road_Analysis1.xlsx')
#       2 Star_Road.to_excel(datatoexcel)
#       3 datatoexcel.save()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     189             raise ValueError("Append mode is not supported with xlsxwriter!")
#     190
# --> 191         super().__init__(
#     192             path,
#     193             engine=engine,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
# ...

# %%
file_name = "Star_Road_Analysis1.xlsx"

# %%
Star_Road.to_excel("C:\Users\saurabh lembhe\Desktop\Star_Road_Analysis1.xlsx")
# Out:
#   File "C:\Users\saurabh lembhe\AppData\Local\Temp\ipykernel_16072\3781591969.py", line 1
#     Star_Road.to_excel("C:\Users\saurabh lembhe\Desktop\Star_Road_Analysis1.xlsx")
#                                                                                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
Star_Road.to_excel("C:/Users/saurabh lembhe/Desktop/Star_Road_Analysis1.xlsx")
#Exported Star_Road data frame into excel for data visualization
